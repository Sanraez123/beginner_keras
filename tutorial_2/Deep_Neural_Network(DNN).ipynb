# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/keras tutorial/Deep Neural Network/HousingPrices.csv')

# %%
df.head()
# Out:
#    YearBuilt  2ndFlrSF  GrLivArea  FullBath  HalfBath  BedroomAbvGr  \
# 0       2003       854       1710         2         1             3
# 1       1976         0       1262         2         0             3
# 2       2001       866       1786         2         1             3
# 3       1915       756       1717         1         0             3
# 4       2000      1053       2198         2         1             4
#
#    TotRmsAbvGrd  YrSold  SalePrice
# 0             8    2008     208500
# 1             6    2007     181500
# 2             6    2008     223500
# 3             7    2006     140000
# 4             9    2008     250000

# %%
X = df.drop(columns=['SalePrice'])
Y = df[['SalePrice']]

# %%
model=tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Dense(8, activation='relu', input_shape=(8,)))
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X, Y, epochs=30, callbacks=[tf.keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Epoch 1/30
# 32/46 [===================>..........] - ETA: 0s - loss: 39954022400.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 46/46 [==============================] - 1s 2ms/step - loss: 39008165888.0000
# Epoch 2/30
# 33/46 [====================>.........] - ETA: 0s - loss: 39038062592.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 46/46 [==============================] - 0s 2ms/step - loss: 38823985152.0000
# Epoch 3/30
# 27/46 [================>.............] - ETA: 0s - loss: 38704091136.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 46/46 [==============================] - 0s 2ms/step - loss: 38269026304.0000
# Epoch 4/30
# 27/46 [================>.............] - ETA: 0s - loss: 36265152512.0000
# ...

# %%
test_data = np.array([2003,	854,	1710,	2,	1,	3,	8,	2008])
print(model.predict(test_data.reshape(1,8)))
# Out:
# [[206560.08]]

# %%
model.save("ML_housing_price_predict.h5")

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/keras tutorial/Deep Neural Network/ML_housing_price_predict.h5')

# %%
test_data = np.array([2003,	854,	1710,	2,	1,	3,	8,	2008])
print(model.predict(test_data.reshape(1,8)))
# Out:
# [[206560.08]]
